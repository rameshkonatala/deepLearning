# %%
import tensorflow as tf

# %%
sess = tf.InteractiveSession()
W = tf.placeholder(tf.float32, shape=(10, 784))
x = tf.placeholder(tf.float32, shape=(784, 1))
y = tf.placeholder(tf.float32, shape=(10, 1))
b = tf.placeholder(tf.float32, shape=(10, 1))
z = tf.nn.softmax(tf.add(tf.matmul(W,x),b))
writer = tf.summary.FileWriter('./graphs/nn', tf.get_default_graph())
sess.run(z)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-5-5b76ceda02ff> in <module>()
#       6 z = tf.nn.softmax(tf.add(tf.matmul(W,x),b))
#       7 writer = tf.summary.FileWriter('./graphs/nn', tf.get_default_graph())
# ----> 8 sess.run(z)
#
# /home/rameshkonatala/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/rameshkonatala/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
# ...
